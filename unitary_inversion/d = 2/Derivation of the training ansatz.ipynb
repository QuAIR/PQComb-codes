# %% [markdown]
# **Derivation of the training ansatz for the 4-call qubit-unitary inversion protocol**

# %%
from quairkit.application import PQCombNet
from quairkit.qinfo import dagger
from quairkit.circuit import Circuit
from torch.nn import ModuleList, Parameter
from quairkit.database import zero_state, universal_qudit, universal3
from quairkit.operator import ParamOracle
import torch
import quairkit

quairkit.set_dtype("complex128")

# %%
num_slots, ancilla_qubits = 4, 3
num_qubits = ancilla_qubits + 1
num_V = num_slots + 1
slot_dim = 2

# %% [markdown]
# Initial training ansatz that found 0.99 training fidelity, where each comb tooth is a 16-dimensional universal unitary tunable by 255 parameters.

# %%
net = PQCombNet(
    target_function=dagger,
    num_slots=num_slots,
    ancilla=ancilla_qubits,
    slot_dim=slot_dim,
    train_mode="process",
)

net.plot()

# %%
net.train()

# %% [markdown]
# The ansatz further improved by guessing all entangled gates between ancilla qubits and the main system to be controlled universal qubit-gates $\textrm{U}3$.

# %%
V_circuit_list_b = ModuleList()
for i in range(num_V):
    V_circuit = Circuit(num_qubits)
    if i > 0:
        V_circuit.cu([0, 3])
        V_circuit.cu([1, 3])
        V_circuit.cu([2, 3])
    V_circuit.universal_qudits(list(range(ancilla_qubits)))
    V_circuit.cu([2, 3])
    V_circuit.cu([1, 3])
    V_circuit.cu([0, 3])
    V_circuit_list_b.append(V_circuit)
net.V_circuit_list = V_circuit_list_b
net.plot()
net.train()

# %% [markdown]
# The ansatz further improved by guessing most of universal qubit-gates to be Pauli operators, and the first universal three-qubit gates to be Hadamard gates. The best training fidelity can approach 0.999 at this stage.

# %%
V_circuit_list_c = ModuleList()
for i in range(num_V):
    V_circuit = Circuit(num_qubits)
    if i == 0:
        V_circuit.h(list(range(ancilla_qubits)))
    else:
        V_circuit.cz([0, 3])
        V_circuit.cy([1, 3])
        V_circuit.cx([2, 3])
        V_circuit.universal_qudits(list(range(ancilla_qubits)))

    if i < num_slots:
        V_circuit.cx([2, 3])
        V_circuit.cy([1, 3])
        V_circuit.cz([0, 3])
    else:
        V_circuit.cu([2, 3])
        V_circuit.cu([1, 3])
        V_circuit.cu([0, 3])
    V_circuit_list_c.append(V_circuit)
net.V_circuit_list = V_circuit_list_c
net.plot()
net.train()

# %% [markdown]
# The ansatz further improved by guessing low coherence of the first ancilla qubit, which needs to be clean at the end: the amplitude on $\ket{0}$ is now proportional to the training fidelity.

# %%
V_circuit_list_d = ModuleList()
for i in range(num_V):
    V_circuit = Circuit(num_qubits)
    if i == 0:
        V_circuit.h(list(range(1, ancilla_qubits)))
    else:
        V_circuit.cy([1, 3])
        V_circuit.cx([2, 3])
        V_circuit.universal_qudits(list(range(ancilla_qubits)))

    if i < num_slots:
        V_circuit.cx([2, 3])
        V_circuit.cy([1, 3])
    else:
        V_circuit.cy([2, 3])
        V_circuit.cx([1, 3])
    V_circuit_list_d.append(V_circuit)
net.V_circuit_list = V_circuit_list_d
net.plot()
net.train(
    projector=zero_state(1).density_matrix.kron(torch.eye(2 ** (ancilla_qubits - 1)))
)
# Out:
# [pqcomb_dagger | process | 372390 | 0	0.0449s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-01, Loss: 0.86109104, Fid: 0.13488786
# [pqcomb_dagger | process | 372390 | 100	0.0260s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-01, Loss: 0.06980636, Fid: 0.92935286
# [pqcomb_dagger | process | 372390 | 200	0.0261s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-01, Loss: 0.01364714, Fid: 0.98624525
# [pqcomb_dagger | process | 372390 | 300	0.0261s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-01, Loss: 0.00330521, Fid: 0.99665400
# [pqcomb_dagger | process | 372390 | 400	0.0300s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-02, Loss: 0.00224373, Fid: 0.99772905
# [pqcomb_dagger | process | 372390 | 500	0.0310s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-02, Loss: 0.00198422, Fid: 0.99799162
# [pqcomb_dagger | process | 372390 | 600	0.0282s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-02, Loss: 0.00173603, Fid: 0.99824267
# [pqcomb_dagger | process | 372390 | 700	0.0293s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-02, Loss: 0.00150572, Fid: 0.99847564
# [pqcomb_dagger | process | 372390 | 800	0.0294s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-02, Loss: 0.00129694, Fid: 0.99868682
# Progress |████----------------------------------------------| 8.7%

# %% [markdown]
# The ansatz further improved by guessing the parity and duality relations among four teeth of the comb. This ansatz can obtain fidelity close to 1, and is eventually reduced to the optimal circuit.

# %%
V_circuit_list_e = ModuleList()
G_param = Parameter(
    torch.randn(1, 2 ** (2 * ancilla_qubits) - 1, dtype=quairkit.get_float_dtype())
)
G_dagger = ParamOracle(
    lambda param: dagger(universal_qudit(theta=param, dimension=2**ancilla_qubits)),
    G_param[0],
    num_acted_param=G_param[0].__len__(),
    system_idx=list(range(ancilla_qubits)),
)
for i in range(num_V):
    V_circuit = Circuit(num_qubits)
    if i == 0:
        V_circuit.h(list(range(1, ancilla_qubits)))
        V_circuit.cx([2, 3])
        V_circuit.cy([1, 3])
    elif i == 1:
        V_circuit.cy([1, 3])
        V_circuit.cx([2, 3])
        V_circuit.universal_qudits(list(range(ancilla_qubits)), param=G_param[0])
        V_circuit.u3([0])
        V_circuit.cx([2, 3])
        V_circuit.cy([1, 3])
    elif i == 2:
        V_circuit.cy([1, 3])
        V_circuit.cx([2, 3])
        V_circuit.append(G_dagger)
        V_circuit.cx([2, 3])
        V_circuit.cy([1, 3])
    elif i == 3:
        V_circuit.cy([1, 3])
        V_circuit.cx([2, 3])
        V_circuit.universal_qudits(list(range(1, ancilla_qubits)))
        V_circuit.universal_qudits(list(range(ancilla_qubits)), param=G_param[0])
        V_circuit.u3([0])
        V_circuit.cx([2, 3])
        V_circuit.cy([1, 3])
    elif i == 4:
        V_circuit.cy([1, 3])
        V_circuit.cx([2, 3])
        V_circuit.append(G_dagger)
        V_circuit.universal_qudits(list(range(1, ancilla_qubits)))
        V_circuit.cy([2, 3])
        V_circuit.cx([1, 3])
    V_circuit_list_e.append(V_circuit)
net.V_circuit_list = V_circuit_list_e
net.plot()
net.train(
    projector=zero_state(1).density_matrix.kron(torch.eye(2 ** (ancilla_qubits - 1)))
)
# Out:
# [pqcomb_dagger | process | 372390 | 0	0.0298s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-01, Loss: 0.86479652, Fid: 0.13555297
# [pqcomb_dagger | process | 372390 | 100	0.0343s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-01, Loss: 0.60105885, Fid: 0.39495926
# [pqcomb_dagger | process | 372390 | 200	0.0342s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-01, Loss: 0.59212465, Fid: 0.40572516
# [pqcomb_dagger | process | 372390 | 300	0.0349s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-01, Loss: 0.58966194, Fid: 0.41069566
# [pqcomb_dagger | process | 372390 | 400	0.0348s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-01, Loss: 0.58750681, Fid: 0.41466529
# [pqcomb_dagger | process | 372390 | 500	0.0332s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-01, Loss: 0.58616126, Fid: 0.41717566
# [pqcomb_dagger | process | 372390 | 600	0.0334s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-01, Loss: 0.58539570, Fid: 0.41860702
# [pqcomb_dagger | process | 372390 | 700	0.0339s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-04, Loss: 0.58489182, Fid: 0.41950306
# [pqcomb_dagger | process | 372390 | 709	0.0334s] slot_dim: 2, slots: 4, aux_qubits: 3, LR: 1.00e-05, Loss: 0.58488986, Fid: 0.41949692
# [pqcomb_dagger | process | 372390] Finished training with Fidelity: 0.41949692
